# %%
import pandas as pd
df=pd.read_csv("/home/parth/iplgameathon/fantasy-sports-machine-learning/data/ipl/player_form_scores.csv")

# %%
df.head(5)
# Out:
#             Player  Batting Form  Bowling Form  Fielding Form  Credits  \
# 0      Abdul Samad     75.211864     44.209040      70.536723      6.5
# 1  Abhinav Manohar     44.378531     48.305085      51.327684      6.5
# 2  Abhishek Sharma     91.129944     52.217514      66.440678      8.5
# 3    Abishek Porel     75.423729     48.305085      63.644068      6.5
# 4       Adam Zampa     18.192090     39.632768      26.468927      7.5
#
#   Player Type Team
# 0         BAT  LSG
# 1         BAT  SRH
# 2         ALL  SRH
# 3          WK   DC
# 4        BOWL  SRH

# %%
sorte=df.sort_values('Batting Form',ascending=False)
sorte.head(15)
# Out:
#                Player  Batting Form  Bowling Form  Fielding Form  Credits  \
# 151  Suryakumar Yadav     93.926554     48.305085      69.124294      9.0
# 47   Heinrich Klaasen     92.768362     48.305085      89.519774      9.0
# 10      Andre Russell     91.511299     69.025424      65.310734      8.5
# 143       Shivam Dube     91.313559     22.768362      68.135593      8.0
# 136      Sanju Samson     91.299435     48.305085      98.192090      9.0
# 174  Yashasvi Jaiswal     91.158192     22.118644      69.971751      9.0
# 2     Abhishek Sharma     91.129944     52.217514      66.440678      8.5
# 147      Shubman Gill     90.028249     48.305085      66.440678      9.0
# 157       Travis Head     90.000000     22.457627      26.468927      9.0
# 131   Ruturaj Gaikwad     88.983051     48.305085      72.655367      9.0
# 115     Rajat Patidar     88.799435     48.305085      58.813559      8.0
# 48       Ishan Kishan     87.853107     48.305085      93.502825      8.0
# ...

# %%
df1=pd.read_csv("squad.csv")
print(df1.isnull().sum())
print(df1['ESPN player name'].isnull().sum())
# Out:
# Credits             0
# Player Type         0
# Player Name         0
# Team                0
# ESPN player name    6
# dtype: int64
# 6

# %%
import pandas as pd

df2=pd.read_csv("../../src/dream11_dataset_with_rolling_updated.csv")
sorted=df2.sort_values('points',ascending=False)
sorted.head(5)
# Out:
#         match_id       player                   team             opposition  \
# 5498  2024-04-16    SP Narine  Kolkata Knight Riders       Rajasthan Royals
# 4327  2023-05-12  Rashid Khan         Gujarat Titans         Mumbai Indians
# 2783  2022-05-18    Q de Kock   Lucknow Super Giants  Kolkata Knight Riders
# 3976  2023-04-30  YBK Jaiswal       Rajasthan Royals         Mumbai Indians
# 5691  2024-04-23   MP Stoinis   Lucknow Super Giants    Chennai Super Kings
#
#                                          venue  season     role   runs  \
# 5498                     Eden Gardens, Kolkata    2024  Unknown  109.0
# 4327                  Wankhede Stadium, Mumbai    2023  Unknown   79.0
# 2783        Dr DY Patil Sports Academy, Mumbai    2022  Unknown  140.0
# 3976                  Wankhede Stadium, Mumbai    2023  Unknown  124.0
# 5691  MA Chidambaram Stadium, Chepauk, Chennai    2024  Unknown  124.0
#
#       balls_faced  fours  ...  runs_conceded  balls_bowled  dot_balls  \
# ...

# %%
import pandas as pd

df2=pd.read_csv("../../src/dream11_dataset_with_rolling.csv")
sorted=df2.sort_values('points',ascending=False)
sorted.head(5)
# Out:
#         match_id       player                   team  \
# 4341  2023-05-12  Rashid Khan         Gujarat Titans
# 5505  2024-04-16    SP Narine  Kolkata Knight Riders
# 3894  2023-04-29     MR Marsh         Delhi Capitals
# 441   2021-04-25    RA Jadeja    Chennai Super Kings
# 2776  2022-05-18    Q de Kock   Lucknow Super Giants
#
#                        opposition                               venue  season  \
# 4341               Mumbai Indians            Wankhede Stadium, Mumbai    2023
# 5505             Rajasthan Royals               Eden Gardens, Kolkata    2024
# 3894          Sunrisers Hyderabad         Arun Jaitley Stadium, Delhi    2023
# 441   Royal Challengers Bangalore            Wankhede Stadium, Mumbai    2021
# 2776        Kolkata Knight Riders  Dr DY Patil Sports Academy, Mumbai    2022
#
#          role  runs  balls_faced  fours  ...  runs_conceded  balls_bowled  \
# 4341  Unknown    79           32      3  ...             30            24
# ...
